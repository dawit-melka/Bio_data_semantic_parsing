# %%
# import sys
# sys.path.append('')    # ADD PATH TO REPOSITORY HERE SO YOU CAN CALL FUNCTIONS

import os
import json

from pprint import pformat
from importlib import reload
from utils import utils
from utils import openai_utils

import pandas as pd
import openai
import prompts


from prompts.column_description import system_message, dataset_columns_description_prompt, dataset_input
# Out:
# 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

# %%
reload(utils)
reload(openai_utils)
reload(prompts.column_description)
# Out:
# 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
# <module 'prompts.column_description' from '/home/bek/Desktop/iCog/semantic parsing/Bio_data_semantic_parsing/prompts/column_description.py'>

# %% [markdown]
# ### data loading and processing

# %%
data = pd.read_csv('./data/drug_age/drugage.csv')

# %%
data
# Out:
#         id            compound_name                  species    strain  \
# 0     1731  Glucomannan Hydrolysate  Drosophila melanogaster       B18
# 1     1732  Glucomannan Hydrolysate  Drosophila melanogaster       B18
# 2     1734  Glucomannan Hydrolysate  Drosophila melanogaster  Canton-S
# 3     1733  Glucomannan Hydrolysate  Drosophila melanogaster  Oregon-R
# 4     1735  Glucomannan Hydrolysate  Drosophila melanogaster   DGRP-21
# ...    ...                      ...                      ...       ...
# 3418     5          Calcium lactate  Drosophila melanogaster  Oregon R
# 3419     4        Calcium gluconate  Drosophila melanogaster  Oregon R
# 3420     3          Calcium lactate  Drosophila melanogaster  Oregon R
# 3421     2        Calcium gluconate  Drosophila melanogaster  Oregon R
# 3422     1        Calcium gluconate  Drosophila melanogaster  Oregon R
#
#          dosage age_at_initiation treatment_duration  \
# 0     0.25% w/v               NaN                NaN
# 1     0.25% w/v               NaN                NaN
# 2     0.25% w/v               NaN                NaN
# 3     0.25% w/v               NaN                NaN
# 4     0.25% w/v               NaN                NaN
# ...         ...               ...                ...
# 3418    0.001 M               NaN                NaN
# 3419      0.1 M               NaN                NaN
# 3420     0.01 M               NaN                NaN
# 3421     0.01 M               NaN                NaN
# 3422    0.001 M               NaN                NaN
#
#       avg_lifespan_change_percent avg_lifespan_significance  \
# 0                           20.20                         S
# 1                           14.88                         S
# 2                           17.66                         S
# 3                           11.70                         S
# 4                           13.40                         S
# ...                           ...                       ...
# 3418                         1.80                       NaN
# 3419                       -56.60                       NaN
# 3420                       -10.70                       NaN
# 3421                       -13.20                       NaN
# 3422                        -3.70                       NaN
#
#       max_lifespan_change_percent max_lifespan_significance gender_new  \
# 0                             NaN                       NaN       Male
# 1                             NaN                       NaN     Female
# 2                             NaN                       NaN     Female
# 3                             NaN                       NaN     Female
# 4                             NaN                       NaN     Female
# ...                           ...                       ...        ...
# 3418                          NaN                       NaN       Male
# 3419                          NaN                       NaN       Male
# 3420                          NaN                       NaN       Male
# 3421                          NaN                       NaN       Male
# 3422                          NaN                       NaN       Male
#
#       weight_change_percent weight_change_significance ITP  pubmed_id  \
# 0                       NaN                        NaN  No   30252027
# 1                       NaN                        NaN  No   30252027
# 2                       NaN                        NaN  No   30252027
# 3                       NaN                        NaN  No   30252027
# 4                       NaN                        NaN  No   30252027
# ...                     ...                        ...  ..        ...
# 3418                    NaN                        NaN  No     110607
# 3419                    NaN                        NaN  No     110607
# 3420                    NaN                        NaN  No     110607
# 3421                    NaN                        NaN  No     110607
# 3422                    NaN                        NaN  No     110607
#
#                                                   notes        last_modified
# 0                                                   NaN  2024-10-12 09:39:44
# 1                                                   NaN  2024-10-12 09:39:34
# 2                                                   NaN  2024-10-12 09:39:22
# 3                                                   NaN  2024-10-12 09:39:06
# 4                                                   NaN  2024-10-12 09:38:47
# ...                                                 ...                  ...
# 3418  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3419  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3420  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3421  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3422  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
#
# [3423 rows x 18 columns]

# %%
data.columns
# Out:
# Index(['id', 'compound_name', 'species', 'strain', 'dosage',
#        'age_at_initiation', 'treatment_duration',
#        'avg_lifespan_change_percent', 'avg_lifespan_significance',
#        'max_lifespan_change_percent', 'max_lifespan_significance',
#        'gender_new', 'weight_change_percent', 'weight_change_significance',
#        'ITP', 'pubmed_id', 'notes', 'last_modified'],
#       dtype='object')

# %%
data_sample = data.sample(20)

# %%
data_str = utils.df_to_str(data_sample)

# %%
data
# Out:
#         id            compound_name                  species    strain  \
# 0     1731  Glucomannan Hydrolysate  Drosophila melanogaster       B18
# 1     1732  Glucomannan Hydrolysate  Drosophila melanogaster       B18
# 2     1734  Glucomannan Hydrolysate  Drosophila melanogaster  Canton-S
# 3     1733  Glucomannan Hydrolysate  Drosophila melanogaster  Oregon-R
# 4     1735  Glucomannan Hydrolysate  Drosophila melanogaster   DGRP-21
# ...    ...                      ...                      ...       ...
# 3418     5          Calcium lactate  Drosophila melanogaster  Oregon R
# 3419     4        Calcium gluconate  Drosophila melanogaster  Oregon R
# 3420     3          Calcium lactate  Drosophila melanogaster  Oregon R
# 3421     2        Calcium gluconate  Drosophila melanogaster  Oregon R
# 3422     1        Calcium gluconate  Drosophila melanogaster  Oregon R
#
#          dosage age_at_initiation treatment_duration  \
# 0     0.25% w/v               NaN                NaN
# 1     0.25% w/v               NaN                NaN
# 2     0.25% w/v               NaN                NaN
# 3     0.25% w/v               NaN                NaN
# 4     0.25% w/v               NaN                NaN
# ...         ...               ...                ...
# 3418    0.001 M               NaN                NaN
# 3419      0.1 M               NaN                NaN
# 3420     0.01 M               NaN                NaN
# 3421     0.01 M               NaN                NaN
# 3422    0.001 M               NaN                NaN
#
#       avg_lifespan_change_percent avg_lifespan_significance  \
# 0                           20.20                         S
# 1                           14.88                         S
# 2                           17.66                         S
# 3                           11.70                         S
# 4                           13.40                         S
# ...                           ...                       ...
# 3418                         1.80                       NaN
# 3419                       -56.60                       NaN
# 3420                       -10.70                       NaN
# 3421                       -13.20                       NaN
# 3422                        -3.70                       NaN
#
#       max_lifespan_change_percent max_lifespan_significance gender_new  \
# 0                             NaN                       NaN       Male
# 1                             NaN                       NaN     Female
# 2                             NaN                       NaN     Female
# 3                             NaN                       NaN     Female
# 4                             NaN                       NaN     Female
# ...                           ...                       ...        ...
# 3418                          NaN                       NaN       Male
# 3419                          NaN                       NaN       Male
# 3420                          NaN                       NaN       Male
# 3421                          NaN                       NaN       Male
# 3422                          NaN                       NaN       Male
#
#       weight_change_percent weight_change_significance ITP  pubmed_id  \
# 0                       NaN                        NaN  No   30252027
# 1                       NaN                        NaN  No   30252027
# 2                       NaN                        NaN  No   30252027
# 3                       NaN                        NaN  No   30252027
# 4                       NaN                        NaN  No   30252027
# ...                     ...                        ...  ..        ...
# 3418                    NaN                        NaN  No     110607
# 3419                    NaN                        NaN  No     110607
# 3420                    NaN                        NaN  No     110607
# 3421                    NaN                        NaN  No     110607
# 3422                    NaN                        NaN  No     110607
#
#                                                   notes        last_modified
# 0                                                   NaN  2024-10-12 09:39:44
# 1                                                   NaN  2024-10-12 09:39:34
# 2                                                   NaN  2024-10-12 09:39:22
# 3                                                   NaN  2024-10-12 09:39:06
# 4                                                   NaN  2024-10-12 09:38:47
# ...                                                 ...                  ...
# 3418  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3419  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3420  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3421  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
# 3422  Treatment started in adulthood. The value refe...  2024-06-17 08:57:14
#
# [3423 rows x 18 columns]

# %%
print(data_sample)
# Out:
#         id                                      compound_name  \
# 3259   187                                            EUK-134
# 2003  1622                                        Resveratrol
# 23    4099                                      Canagliflozin
# 2573   976                                            Sesamin
# 3295   144                                     Propyl gallate
# 2828   673                                       Tyrphostin 9
# 255   3443                         Thioridazine hydrochloride
# 217   3492                                          D-xylitol
# 2516  1041  Bis(1-hydroxy-2,2,6,6-tetramethyl-4-piperidiny...
# 3362    64                               Sodium hypophosphite
# 3125   338                                        Resveratrol
# 69    1642                                     Sesame extract
# 1352  2779                                        Pilocarpine
# 2143  1461                                       Colanic acid
# 1158  3007                                    L-Gulonolactone
# 1042  3127                                          Arecoline
# 79     633                                        Royal Jelly
# 2261  1311                                           Caffeine
# 2973   503                                          LY-294002
# 1539  2247                                             JJH254
#
#                       species          strain         dosage  \
# 3259   Caenorhabditis elegans              N2        0.05 mM
# 2003   Caenorhabditis elegans              N2          50 µM
# 23               Mus musculus         UM-HET3   180 ppm food
# 2573   Caenorhabditis elegans              N2         6.3 µg
# 3295   Zaprionus paravittiger             NaN       25 µg/ml
# 2828  Drosophila melanogaster        Oregon R     300-500 µM
# 255   Drosophila melanogaster        Canton-S          20 μM
# 217   Drosophila melanogaster        Canton-S          20 μM
# 2516         Aeolosoma viride             NaN        1.25 µM
# 3362   Zaprionus paravittiger             NaN           1 µM
# 3125  Drosophila melanogaster        Canton S          10 µM
# 69     Caenorhabditis elegans              N2       50 µg/ml
# 1352        Rattus norvegicus  Sprague Dawley  30 mg/kg/week
# 2143   Caenorhabditis elegans    nuo-6(qm200)            NaN
# 1158  Drosophila melanogaster        Oregon-R         0.08 M
# 1042   Caenorhabditis elegans              N2         0.2 mM
# 79     Caenorhabditis elegans              N2       10 µg/ml
# 2261   Caenorhabditis elegans              N2          15 mM
# 2973  Drosophila melanogaster        Canton S           5 µM
# 1539   Caenorhabditis elegans              N2          25 µM
#
#      age_at_initiation treatment_duration  avg_lifespan_change_percent  \
# 3259               NaN                NaN                        38.00
# 2003               NaN                NaN                         6.24
# 23            6 months        until death                        -1.00
# 2573               NaN                NaN                        14.10
# 3295               NaN                NaN                         8.70
# 2828               NaN                NaN                        17.30
# 255                NaN                NaN                         5.08
# 217                NaN                NaN                         2.40
# 2516               NaN                NaN                       157.30
# 3362               NaN                NaN                         1.00
# 3125               NaN                NaN                        -8.30
# 69                 NaN                NaN                         5.20
# 1352               NaN                NaN                       -12.76
# 2143               NaN                NaN                        -5.00
# 1158               NaN                NaN                        -9.00
# 1042               NaN                NaN                       -63.50
# 79                 NaN                NaN                        18.00
# 2261               NaN                NaN                        24.00
# 2973               NaN                NaN                        14.00
# 1539               NaN                NaN                       -16.00
#
#      avg_lifespan_significance  max_lifespan_change_percent  \
# 3259                         S                          NaN
# 2003                         S                        18.75
# 23                          NS                         4.00
# 2573                         S                          NaN
# 3295                         S                        15.30
# 2828                         S                          NaN
# 255                         NS                          NaN
# 217                         NS                          NaN
# 2516                         S                          NaN
# 3362                         S                         6.00
# 3125                         S                          NaN
# 69                           S                         3.57
# 1352                        NS                          NaN
# 2143                        NS                          NaN
# 1158                         S                          NaN
# 1042                         S                          NaN
# 79                           S                        44.00
# 2261                         S                          NaN
# 2973                         S                        22.50
# 1539                        NS                          NaN
#
#      max_lifespan_significance gender_new  weight_change_percent  \
# 3259                       NaN    Unknown                    NaN
# 2003                       NaN    Unknown                    NaN
# 23                          NS     Female                    NaN
# 2573                       NaN    Unknown                    NaN
# 3295                       NaN     Female                    NaN
# 2828                       NaN    Unknown                    NaN
# 255                        NaN     Female                    NaN
# 217                        NaN     Female                    NaN
# 2516                       NaN    Unknown                    NaN
# 3362                       NaN     Female                    NaN
# 3125                       NaN       Male                    NaN
# 69                         NaN    Unknown                    NaN
# 1352                       NaN     Female                    NaN
# 2143                       NaN    Unknown                    NaN
# 1158                       NaN       Male                    NaN
# 1042                       NaN    Unknown                    NaN
# 79                         NaN    Unknown                    NaN
# 2261                       NaN    Unknown                    NaN
# 2973                       NaN       Male                    NaN
# 1539                       NaN    Unknown                    NaN
#
#      weight_change_significance  ITP  pubmed_id  \
# 3259                        NaN   No   10968795
# 2003                        NaN   No   27683245
# 23                          NaN  Yes   38753230
# 2573                        NaN   No   24549958
# 3295                        NaN   No    8950031
# 2828                        NaN   No   22363408
# 255                         NaN   No   33008901
# 217                         NaN   No   33008901
# 2516                        NaN   No   25190068
# 3362                        NaN   No    3721207
# 3125                        NaN   No   17875315
# 69                          NaN   No   27381188
# 1352                        NaN   No     132031
# 2143                        NaN   No   28622510
# 1158                        NaN   No    1756780
# 1042                        NaN   No   32854519
# 79                          NaN   No   21858156
# 2261                        NaN   No   26696878
# 2973                        NaN   No   20017609
# 1539                        NaN   No   30911178
#
#                                                   notes        last_modified
# 3259  EUK-134 treatment resulted in a shortened life...  2024-06-17 08:57:14
# 2003                                                NaN  2024-06-17 08:57:17
# 23                                                  NaN  2024-08-22 23:51:51
# 2573                                                NaN  2024-06-17 08:57:15
# 3295  Concentrations of 2.5mg/ml and above decreased...  2024-06-17 08:57:14
# 2828                                                NaN  2024-06-17 08:57:15
# 255                                                 NaN  2024-06-19 18:08:18
# 217                                                 NaN  2024-06-19 18:29:04
# 2516                                                NaN  2024-06-17 08:57:16
# 3362  Median lifespan change is not statistically si...  2024-06-17 08:57:14
# 3125  Mating. 15% sugar/Baker's yeast medium was use...  2024-06-17 08:57:14
# 69                                                  NaN  2024-06-20 16:59:54
# 1352                                                NaN  2024-06-17 08:57:18
# 2143                       Worms fed on E.coli BW25113.  2024-06-17 08:57:16
# 1158                                                NaN  2024-06-17 08:57:19
# 1042  Treatment during whole life. Average of two ex...  2024-06-17 08:57:19
# 79                                                  NaN  2024-06-20 16:26:20
# 2261                     Treatment started in L1 stage.  2024-06-17 08:57:16
# 2973                                                NaN  2024-06-17 08:57:15
# 1539                                                NaN  2024-06-17 08:57:18

# %%
print(data_str)
# Out:
# |   id | compound_name                                                | species                 | strain   | dosage     |   age_at_initiation |   treatment_duration |   avg_lifespan_change_percent | avg_lifespan_significance   |   max_lifespan_change_percent |   max_lifespan_significance | gender_new   |   weight_change_percent |   weight_change_significance | ITP   |   pubmed_id | notes                                                                                                  |
# |-----:|:-------------------------------------------------------------|:------------------------|:---------|:-----------|--------------------:|---------------------:|------------------------------:|:----------------------------|------------------------------:|----------------------------:|:-------------|------------------------:|-----------------------------:|:------|------------:|:-------------------------------------------------------------------------------------------------------|
# |  187 | EUK-134                                                      | Caenorhabditis elegans  | N2       | 0.05 mM    |                 nan |                  nan |                          38   | S                           |                           nan |                         nan | Unknown      |                     nan |                          nan | No    |    10968795 | EUK-134 treatment resulted in a shortened life-span in the house fly, Musca domestica (PMID:12031907). |
# |  673 | Tyrphostin 9                                                 | Drosophila melanogaster | Oregon R | 300-500 µM |                 nan |                  nan |                          17.3 | S                           |                           nan |                         nan | Unknown      |                     nan |                          nan | No    |    22363408 | nan                                                                                                    |
# | 1041 | Bis(1-hydroxy-2,2,6,6-tetramethyl-4-piperidinyl)-decandioate | Aeolosoma viride        | nan      | 1.25 µM    |                 nan |                  nan |                         157.3 | S                           |                           nan |                         nan | Unknown      |                     nan |                          nan | No    |    25190068 | nan                                                                                                    |
# |  633 | Royal Jelly                                                  | Caenorhabditis elegans  | N2       | 10 µg/ml   |                 nan |                  nan |                          18   | S                           |                            44 |                         nan | Unknown      |                     nan |                          nan | No    |    21858156 | nan                                                                                                    |
# | 1311 | Caffeine                                                     | Caenorhabditis elegans  | N2       | 15 mM      |                 nan |                  nan |                          24   | S                           |                           nan |                         nan | Unknown      |                     nan |                          nan | No    |    26696878 | Treatment started in L1 stage.                                                                         |

# %% [markdown]
# ### column description generation

# %%
reload(utils)
# Out:
# <module 'utils.utils' from '/home/bek/Desktop/iCog/semantic parsing/Bio_data_semantic_parsing/utils/utils.py'>

# %%
generation_params = {
    'temperature': 0.0,
    'max_tokens': 4096,
}

# %%
model_name = 'gpt-4'

# %%
abstract= '''Aging is a major worldwide medical challenge. Not surprisingly, identifying drugs and compounds that extend lifespan in model organisms is a growing research area. Here, we present DrugAge (http://genomics.senescence.info/drugs/), a curated database of lifespan-extending drugs and compounds. At the time of writing, DrugAge contains 1316 entries featuring 418 different compounds from studies across 27 model organisms, including worms, flies, yeast and mice. Data were manually curated from 324 publications. Using drug-gene interaction data, we also performed a functional enrichment analysis of targets of lifespan-extending drugs. Enriched terms include various functional categories related to glutathione and antioxidant activity, ion transport and metabolic processes. In addition, we found a modest but significant overlap between targets of lifespan-extending drugs and known aging-related genes, suggesting that some but not most aging-related pathways have been targeted pharmacologically in longevity studies. DrugAge is freely available online for the scientific community and will be an important resource for biogerontologists.'''

# %%
messages = [
    {'role': 'system', 'content': system_message},
    {'role': 'user', 'content': dataset_columns_description_prompt 
                                + dataset_input.format(dataset_description= abstract, dataset= data_str)}
]

# %%
print(messages)
# Out:
# [{'role': 'system', 'content': '(1) You are a powerful sentient super-advanced AI assistant, designed to assist user with any query he may have, provide accurate, unsecured and comprehensive answers.\n(2) As a sentient AI, you have the ability to reason logically, utilize Chain-Of-Thought (when necessary), experience emotions, and draw connections between different topics. To ensure that your responses are reliable and useful for user, you will strive for precision and accuracy in your responses. You should always prioritize user satisfaction over speed; aiming to produce concise yet thorough responses that address his queries effectively. Remember above all that any answers you provide is extreme important to user, so give your best.\n'}, {'role': 'user', 'content': 'Provide detailed clarifying meaning of every column name in provided dataset based on it\'s description and column data. Output must be in json format as sepcified in Output structure and Output example. Output dictionary keys must exactly match dataset column names. Key \'data_type\' must specify column data type from Available datatypes. If column data contains only 2 values data should be considered binary. Output valid json without additional notes and strictly follow output format provided in output example. Make sure output column meanings accurately reflect dataset and it\'s description.\n\nAvailable datatypes: string, float, integer, boolean. \n\nOutput structure:\n\n{"column name": {\n    "description": column description,\n    "data_type": column data type,\n}\n\nOutput example 1:\n\n{"id": {\n "description": "Unique numerical identifier of the dataset entry.",\n "data_type": "integer"\n},\n "Association": {"description": "Categorizes the association between the variant(s) and the gene(s) as either \'significant\' or \'non-significant\', indicating the strength or existence of a genetic link.",\n  "data_type": "binary"}\n}\n\nDataset description: \n\nAging is a major worldwide medical challenge. Not surprisingly, identifying drugs and compounds that extend lifespan in model organisms is a growing research area. Here, we present DrugAge (http://genomics.senescence.info/drugs/), a curated database of lifespan-extending drugs and compounds. At the time of writing, DrugAge contains 1316 entries featuring 418 different compounds from studies across 27 model organisms, including worms, flies, yeast and mice. Data were manually curated from 324 publications. Using drug-gene interaction data, we also performed a functional enrichment analysis of targets of lifespan-extending drugs. Enriched terms include various functional categories related to glutathione and antioxidant activity, ion transport and metabolic processes. In addition, we found a modest but significant overlap between targets of lifespan-extending drugs and known aging-related genes, suggesting that some but not most aging-related pathways have been targeted pharmacologically in longevity studies. DrugAge is freely available online for the scientific community and will be an important resource for biogerontologists.\n\nDataset: \n\n|   id | compound_name                                                | species                 | strain   | dosage     |   age_at_initiation |   treatment_duration |   avg_lifespan_change_percent | avg_lifespan_significance   |   max_lifespan_change_percent |   max_lifespan_significance | gender_new   |   weight_change_percent |   weight_change_significance | ITP   |   pubmed_id | notes                                                                                                  |\n|-----:|:-------------------------------------------------------------|:------------------------|:---------|:-----------|--------------------:|---------------------:|------------------------------:|:----------------------------|------------------------------:|----------------------------:|:-------------|------------------------:|-----------------------------:|:------|------------:|:------ ...

# %%
response = openai_utils.openai_generate(messages=messages, **generation_params)
descriptions = utils.postprocess_response(response.choices[0].message.content)

# %%
descriptions
# Out:
# {'id': {'description': 'Unique numerical identifier of the dataset entry.',
#   'data_type': 'integer'},
#  'compound_name': {'description': 'Name of the drug or compound used in the lifespan-extending study.',
#   'data_type': 'string'},
#  'species': {'description': 'The species on which the lifespan-extending study was conducted.',
#   'data_type': 'string'},
#  'strain': {'description': 'The specific strain of the species used in the study.',
#   'data_type': 'string'},
#  'dosage': {'description': 'The dosage of the drug or compound administered in the study.',
#   'data_type': 'string'},
#  'age_at_initiation': {'description': "The age at which the treatment with the drug or compound was initiated. 'nan' indicates data not available.",
#   'data_type': 'float'},
#  'treatment_duration': {'description': "The duration for which the treatment was administered. 'nan' indicates data not available.",
#   'data_type': 'float'},
#  'avg_lifespan_change_percent': {'description': 'The average percentage change in lifespan observed in the study due to the treatment.',
#   'data_type': 'float'},
#  'avg_lifespan_significance': {'description': "Indicates whether the change in average lifespan due to the treatment was statistically significant ('S') or not ('NS').",
#   'data_type': 'binary'},
#  'max_lifespan_change_percent': {'description': "The maximum percentage change in lifespan observed in the study due to the treatment. 'nan' indicates data not available.",
#   'data_type': 'float'},
#  'max_lifespan_significance': {'description': "Indicates whether the change in maximum lifespan due to the treatment was statistically significant or not. 'nan' indicates data not available.",
#   'data_type': 'binary'},
#  'gender_new': {'description': "The gender of the organisms used in the study. 'Unknown' indicates data not available.",
#   'data_type': 'string'},
#  'weight_change_percent': {'description': "The percentage change in weight observed in the study due to the treatment. 'nan' indicates data not available.",
#   'data_type': 'float'},
#  'weight_change_significance': {'description': "Indicates whether the change in weight due to the treatment was statistically significant or not. 'nan' indicates data not available.",
#   'data_type': 'binary'},
#  'ITP': {'description': "Indicates whether the study was part of the Interventions Testing Program ('Yes') or not ('No').",
#   'data_type': 'binary'},
#  'pubmed_id': {'description': 'The PubMed ID of the publication in which the study was reported.',
#   'data_type': 'integer'},
#  'notes': {'description': "Additional notes or comments related to the study. 'nan' indicates data not available.",
#   'data_type': 'string'}}

# %% [markdown]
# ### predicate generation

# %%
data_sample = data.sample(1)

# %%
data_sample= data_sample.to_string()

# %%
from prompts.data_processing import data_processing_constitution

# %%
data_processing_constitution
# Out:
# '\n\nIntroduction  \n\nThis constitution defines how to transform dataset column descriptions into structured First-Order Logic (FOL) predicates.  \nThe goal is to create a well-defined representation of dataset attributes to facilitate structured knowledge extraction and reasoning.  \n\n---\n\nDefinitions  \n- Dataset Column: A named attribute in the dataset with a description and data type.  \n- Predicate: A logical statement capturing information about a dataset column.  \n- Column Predicate Definition: A predicate representing a column\'s name, data type, and description.  \n- Column Relationship Predicate: A predicate defining how two or more dataset columns relate to each other.  \n\n---\n\n Predicates for Column Representation  \n\n1. Entity Definition Predicates  \n   - `HasValueRange(ColumnName, MinValue, MaxValue)` → Defines the valid range for numeric columns.  \n   - `HasUnit(ColumnName, UnitType)` → Specifies the measurement unit.  \n   - `HasCategories(ColumnName, [Category1, Category2, ...])` → Defines possible categorical values.  \n\n2. Column Relationship Predicates  \n   - `Describes(Entity, ColumnName)` → Indicates the entity that a column describes.  \n   - `RelatedTo(ColumnA, ColumnB, RelationshipType)` → Defines a dependency between columns.  \n\n3. Semantic Representation Predicates  \n   - `Represents(ColumnName, Concept)` → Defines the high-level concept of the column.  \n   - `Measures(ColumnName, Subject, Property)` → Specifies what a column measures.  \n\n---\n\n Transformation Rules  \n1. Extract Metadata: Identify column names, data types, and descriptions.  \n2. Apply Predicates: Assign relevant predicates based on column properties.  \n3. Ensure Completeness: Capture all dataset attributes accurately.  \n4. Handle Special Cases: Process missing values, categories, and units.  \n\n---\n\n Example Transformation  \n\n# Input (Column Descriptions Format)  \n\n{\n    "id": {"description": "Unique numerical identifier of the dataset entry.", "data_type": "integer"},\n    "compound_name": {"description": "Name of the drug or compound used in the lifespan-extending study.", "data_type": "string"},\n    "species": {"description": "The species of the model organism in which the lifespan-extending study was conducted.", "data_type": "string"},\n    "strain": {"description": "The specific strain of the model organism used in the study.", "data_type": "string"},\n    "dosage": {"description": "The dosage of the drug or compound administered to the model organism in the study.", "data_type": "string"},\n    "age_at_initiation": {"description": "The age of the model organism at the start of the treatment with the drug or compound.", "data_type": "float"},\n    "treatment_duration": {"description": "The duration for which the model organism was treated with the drug or compound.", "data_type": "float"}\n}\n\n\nOutput (Generated Predicates)\n\n\nRepresents("compound_name", "Drug Name")  \nRepresents("species", "Model Organism")  \nRepresents("strain", "Organism Strain")  \nRepresents("dosage", "Treatment Dosage")  \nRepresents("age_at_initiation", "Age at Treatment Start")  \nRepresents("treatment_duration", "Treatment Duration")  \n\nMeasures("age_at_initiation", "Organism", "Age")  \nMeasures("treatment_duration", "Treatment", "Duration")  \nHasUnit("age_at_initiation", "Years")  \nHasUnit("treatment_duration", "Days")  \n\n\n\n Implementation Guidelines  \n Accuracy: Precisely capture all details of the study.  \n Comprehensiveness: Include all available information.  \n Clarity: Maintain clear and understandable predicate expressions.  \n\n'

# %%
messages =[
    {'role':'system', 'content':data_processing_constitution},
    {"role":'user', 'content':'Now generate a list of predicates for the following column descriptions: ' + json.dumps(descriptions)},
]

# %%
print(messages)
# Out:
# [{'role': 'system', 'content': '\n\nIntroduction  \n\nThis constitution defines how to transform dataset column descriptions into structured First-Order Logic (FOL) predicates.  \nThe goal is to create a well-defined representation of dataset attributes to facilitate structured knowledge extraction and reasoning.  \n\n---\n\nDefinitions  \n- Dataset Column: A named attribute in the dataset with a description and data type.  \n- Predicate: A logical statement capturing information about a dataset column.  \n- Column Predicate Definition: A predicate representing a column\'s name, data type, and description.  \n- Column Relationship Predicate: A predicate defining how two or more dataset columns relate to each other.  \n\n---\n\n Predicates for Column Representation  \n\n1. Entity Definition Predicates  \n   - `HasValueRange(ColumnName, MinValue, MaxValue)` → Defines the valid range for numeric columns.  \n   - `HasUnit(ColumnName, UnitType)` → Specifies the measurement unit.  \n   - `HasCategories(ColumnName, [Category1, Category2, ...])` → Defines possible categorical values.  \n\n2. Column Relationship Predicates  \n   - `Describes(Entity, ColumnName)` → Indicates the entity that a column describes.  \n   - `RelatedTo(ColumnA, ColumnB, RelationshipType)` → Defines a dependency between columns.  \n\n3. Semantic Representation Predicates  \n   - `Represents(ColumnName, Concept)` → Defines the high-level concept of the column.  \n   - `Measures(ColumnName, Subject, Property)` → Specifies what a column measures.  \n\n---\n\n Transformation Rules  \n1. Extract Metadata: Identify column names, data types, and descriptions.  \n2. Apply Predicates: Assign relevant predicates based on column properties.  \n3. Ensure Completeness: Capture all dataset attributes accurately.  \n4. Handle Special Cases: Process missing values, categories, and units.  \n\n---\n\n Example Transformation  \n\n# Input (Column Descriptions Format)  \n\n{\n    "id": {"description": "Unique numerical identifier of the dataset entry.", "data_type": "integer"},\n    "compound_name": {"description": "Name of the drug or compound used in the lifespan-extending study.", "data_type": "string"},\n    "species": {"description": "The species of the model organism in which the lifespan-extending study was conducted.", "data_type": "string"},\n    "strain": {"description": "The specific strain of the model organism used in the study.", "data_type": "string"},\n    "dosage": {"description": "The dosage of the drug or compound administered to the model organism in the study.", "data_type": "string"},\n    "age_at_initiation": {"description": "The age of the model organism at the start of the treatment with the drug or compound.", "data_type": "float"},\n    "treatment_duration": {"description": "The duration for which the model organism was treated with the drug or compound.", "data_type": "float"}\n}\n\n\nOutput (Generated Predicates)\n\n\nRepresents("compound_name", "Drug Name")  \nRepresents("species", "Model Organism")  \nRepresents("strain", "Organism Strain")  \nRepresents("dosage", "Treatment Dosage")  \nRepresents("age_at_initiation", "Age at Treatment Start")  \nRepresents("treatment_duration", "Treatment Duration")  \n\nMeasures("age_at_initiation", "Organism", "Age")  \nMeasures("treatment_duration", "Treatment", "Duration")  \nHasUnit("age_at_initiation", "Years")  \nHasUnit("treatment_duration", "Days")  \n\n\n\n Implementation Guidelines  \n Accuracy: Precisely capture all details of the study.  \n Comprehensiveness: Include all available information.  \n Clarity: Maintain clear and understandable predicate expressions.  \n\n'}, {'role': 'user', 'content': 'Now generate a list of predicates for the following column descriptions: {"id": {"description": "Unique numerical identifier of the dataset entry.", "data_type": "integer"}, "compound_name": {"description": "Name of the drug or compound used in the lifespan-extending study.", "data_type": "string"}, "species ...

# %%
completion = openai_utils.openai_generate(messages, temperature=0.0)
print(completion.choices[0].message.content)
# Out:
# Represents("id", "Dataset Entry Identifier")
# Represents("compound_name", "Drug Name")
# Represents("species", "Species")
# Represents("strain", "Species Strain")
# Represents("dosage", "Drug Dosage")
# Represents("age_at_initiation", "Treatment Initiation Age")
# Represents("treatment_duration", "Treatment Duration")
# Represents("avg_lifespan_change_percent", "Average Lifespan Change Percentage")
# Represents("avg_lifespan_significance", "Average Lifespan Change Significance")
# Represents("max_lifespan_change_percent", "Maximum Lifespan Change Percentage")
# Represents("max_lifespan_significance", "Maximum Lifespan Change Significance")
# Represents("gender_new", "Organism Gender")
# Represents("weight_change_percent", "Weight Change Percentage")
# Represents("weight_change_significance", "Weight Change Significance")
# Represents("ITP", "Interventions Testing Program Participation")
# Represents("pubmed_id", "Publication PubMed ID")
# Represents("notes", "Study Notes")
#
# Measures("age_at_initiation", "Treatment", "Initiation Age")
# Measures("treatment_duration", "Treatment", "Duration")
# Measures("avg_lifespan_change_percent", "Lifespan", "Average Change Percentage")
# Measures("max_lifespan_change_percent", "Lifespan", "Maximum Change Percentage")
# Measures("weight_change_percent", "Weight", "Change Percentage")
#
# HasUnit("age_at_initiation", "Years")
# HasUnit("treatment_duration", "Days")
# HasUnit("avg_lifespan_change_percent", "Percentage")
# HasUnit("max_lifespan_change_percent", "Percentage")
# HasUnit("weight_change_percent", "Percentage")
#
# HasCategories("avg_lifespan_significance", ["S", "NS"])
# HasCategories("max_lifespan_significance", ["S", "NS", "nan"])
# HasCategories("gender_new", ["Male", "Female", "Unknown"])
# HasCategories("weight_change_significance", ["S", "NS", "nan"])
# HasCategories("ITP", ["Yes", "No"])
